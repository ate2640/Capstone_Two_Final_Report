# %%
import pandas as pd
df3 = pd.read_csv('df2.csv')

# %%
df3.head()
# Out:
#    depdelay  arrdelay  nonhubairportorigin  smallhubairportorigin  \
# 0         0      -4.0                    1                      0
# 1        -4      11.0                    0                      0
# 2         3      12.0                    0                      0
# 3        -3      24.0                    0                      0
# 4         0      -8.0                    0                      0
#
#    mediumhubairportorigin  largehubairportorigin  nonhubairportdest  \
# 0                       0                      0                  1
# 1                       0                      1                  0
# 2                       0                      1                  0
# 3                       1                      0                  0
# 4                       0                      1                  1
#
#    smallhubairportdest  mediumhubairportdest  largehubairportdest  ...  \
# 0                    0                     0                    0  ...
# ...

# %%
import numpy as np
df3['delayed'] = np.where(df3['delay_sum']>15, 1, 0) #created a new column such that 1 indicates a delayed flight, 0 indicates an on-time flight
df3.head()
# Out:
#    depdelay  arrdelay  nonhubairportorigin  smallhubairportorigin  \
# 0         0      -4.0                    1                      0
# 1        -4      11.0                    0                      0
# 2         3      12.0                    0                      0
# 3        -3      24.0                    0                      0
# 4         0      -8.0                    0                      0
#
#    mediumhubairportorigin  largehubairportorigin  nonhubairportdest  \
# 0                       0                      0                  1
# 1                       0                      1                  0
# 2                       0                      1                  0
# 3                       1                      0                  0
# 4                       0                      1                  1
#
#    smallhubairportdest  mediumhubairportdest  largehubairportdest  ...  \
# 0                    0                     0                    0  ...
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
 
 
# Initialise the Scaler
scaler = StandardScaler()
 
# To scale data
scaler.fit(df3)
# Out:
# StandardScaler()

# %%
>>> import pandas as pd
>>> from sklearn.model_selection import train_test_split
>>> from sklearn.datasets import load_iris

y = df3.delayed
x = df3.drop('delayed', axis = 1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
x_train.head()
# Out:
#          depdelay  arrdelay  nonhubairportorigin  smallhubairportorigin  \
# 514598         25      15.0                    0                      0
# 575583         -1      -9.0                    0                      0
# 1190216        -1     -19.0                    1                      0
# 79253          -3     -11.0                    0                      0
# 1003119        -5      -4.0                    0                      1
#
#          mediumhubairportorigin  largehubairportorigin  nonhubairportdest  \
# 514598                        1                      0                  0
# 575583                        1                      0                  0
# 1190216                       0                      0                  0
# 79253                         0                      1                  0
# 1003119                       0                      0                  0
#
#          smallhubairportdest  mediumhubairportdest  largehubairportdest  ...  \
# ...

# %%
y_train.head()
# Out:
# 514598     1
# 575583     0
# 1190216    0
# 79253      0
# 1003119    0
# Name: delayed, dtype: int32

# %% [markdown]
# ## Now that I've separated the dataset into my training sets and test sets, I will decide which model is best. There are two categories of models: classification and regression. Classification is for discrete labels, but not continuous values (e.g. 0 or 1, yes/no); regression is for continuous values. In my case, I want to find a discrete label (i.e. 1 for a delayed flight, and 0 for an on-time flight). As such, I will explore different classification metrics.

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
print("Precision: ", precision_score(y_test, model.predict(x_test)))
print('recall: ', recall_score(y_test, model.predict(x_test)))
print("F1 score: ", f1_score(y_test, model.predict(x_test)))
# Out:
# Precision:  0.8181818181818182
# recall:  0.3879310344827586
# F1 score:  0.5263157894736843

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)
LR_model = LogisticRegression().fit(x_train,y_train)
LR_model.score(x_test,y_test)
# Out:
# 0.9595

# %%
from sklearn.ensemble import RandomForestClassifier
RFC_model = RandomForestClassifier(random_state = 42).fit(x_train,y_train)
RFC_model.score(x_test,y_test)
# Out:
# 0.964

# %% [markdown]
# #### From these three models, the Logistic Regression and Random Forest Classifier do the best, at 95.95% and 96.4%, respectively; however, it is worth noting that the latter took a notably longer time than the previous.
